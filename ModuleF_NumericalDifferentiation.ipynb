# %% [markdown]
# <a href="https://colab.research.google.com/github/bwada10/MAT421---Computational-Methods/blob/main/ModuleF_NumericalDifferentiation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Chapter 20 - Numerical Differentiation**
#
# Models always change in mathematics and science over time and especailly the functional derivatives used in the models.
#
#
# ---
#
#
#
# **20.1: Numerical Differentiation Problem Statement:**
#
# An evenly spaced set of data points over the domain of the function on some random inteval is called an **Numerical Grid**. The distance between adjacent data points is **spacing** or **step-size**.
#
# ![1.PNG](data:image/png;base64,...)
#
#
#
# ---
#
#
#
# > *Create a numerical grid starting at x = 0 to x = 20:*

# %%
import numpy as np

x = np.linspace(0,20,20)
x
# Out:
# array([ 0.        ,  1.05263158,  2.10526316,  3.15789474,  4.21052632,
#         5.26315789,  6.31578947,  7.36842105,  8.42105263,  9.47368421,
#        10.52631579, 11.57894737, 12.63157895, 13.68421053, 14.73684211,
#        15.78947368, 16.84210526, 17.89473684, 18.94736842, 20.        ])

# %% [markdown]
# **20.2: Finite Differences Approximating Derivatives**
#
# For **Finite difference** approximations of slopes, we can use values in the neighborhood of point x = a, where x is the slope of the point a.
#
#
# ---
#
#
#
# Below are 3 finite difference forumulas:
#
# **Forward Difference:**
#
# ![2.PNG](data:image/png;base64,...)
#
# **Backward Difference:**
#
# ![3.PNG](data:image/png;base64,...)
#
# **Central Difference:**
#
# ![4.PNG](data:image/png;base64,...)
#
#
# ---
#
#
#
# > *Find the derivative of the function f(x) = sin(x) using forward difference:*

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-poster')
# %matplotlib inline

# %%
# step size
h = 0.1
# define grid
x = np.arange(0, 2*np.pi, h) 
# compute function
y = np.sin(x) 

# compute vector of forward differences
forward_diff = np.diff(y)/h 
# compute corresponding grid
x_diff = x[:-1:] 
# compute exact solution
exact_solution = np.cos(x_diff) 

# Plot solution
plt.figure(figsize = (12, 8))
plt.plot(x_diff, forward_diff, '--', \
         label = 'Finite difference approximation')
plt.plot(x_diff, exact_solution, \
         label = 'Exact solution')
plt.legend()
plt.show()

# Compute max error between 
# numerical derivative and exact solution
max_error = max(abs(exact_solution - forward_diff))
print(max_error)
# Out:
# 0.04997515074549317

# %% [markdown]
# As expected, the derivative of f(x) = sin(x) is cos(x) as seen by the graph.

# %% [markdown]
# **20.3: Approximating of Higher Order Derivatives**
#
# We can approximate higher order derivatives using Taylor series. This technique is useful when there is a point around which we have knowledge about a function for all its derivatives.
#
# ---
#
#
#
# > *Approximate the Sine function with the First, Third, Fifth, and Seventh order Taylor Series:*

# %%
x = np.linspace(-np.pi, np.pi, 200)
y = np.zeros(len(x))

labels = ['First Order', 'Third Order', 'Fifth Order', 'Seventh Order']

plt.figure(figsize = (10,8))
for n, label in zip(range(4), labels):
    y = y + ((-1)**n * (x)**(2*n+1)) / np.math.factorial(2*n+1)
    plt.plot(x,y, label = label)

plt.plot(x, np.sin(x), 'k', label = 'Analytic')
plt.grid()
plt.title('Taylor Series Approximations of Various Orders')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# **20.4: Numerical Differentiation with Noise**
#
# Data can be contaminated where the value is off by a small amount called **Noise**. This can occur by inaccuaracy by the measuring device or human error.
#
# ---
#
#
#
# > *Show a graph of Sin(x) Vs Sin(x) + Noise:*

# %%
x = np.arange(0, 2*np.pi, 0.01) 
# compute function
omega = 100
epsilon = 0.05

y = np.sin(x) 
y_noise = y + epsilon*np.cos(omega*x) 

# Plot solution
plt.figure(figsize = (12, 8))
plt.plot(x, y_noise, 'r-', \
         label = 'sin(x) + noise')
plt.plot(x, y, 'b-', \
         label = 'sin(x)')

plt.xlabel('x')
plt.ylabel('y')

plt.legend()
plt.show()
